# %% [markdown]
# # Software Evolution - Practical Session
# ## Laws of software evolution, code counting, code duplication and dependency analysis
# ## Academic year 2022-2023

# %% [markdown]
# ### Write your answers under the questions that are present in this notebook
#
# ### Read Section 1 and Section 2 in the provided description document before proceeding with the following section

# %%
import os
import json
import scipy.stats
from tqdm import tqdm
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import subprocess
import math
from pandas import option_context
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# %% [markdown]
# ## 2. Verifying laws of software evolution

# %%
#Enter the path where the Eucalyptus project is present
eucalyptus_project_path = '~/Documents/SE/eucalyptus'

# %% [markdown]
# ### 2.1 Data prepocessing
# 1. Get all the tags present in the eucalyptus project using CLOC
# 2. Filter out the tags that do not correspond to official releases

# %% [markdown]
# Code hint:
# To get the tags that are present in the project - "command = f'git -C {eucalyptus_project_path} tag -l --format="%(refname:short)" | sort -r'"
# To read the terminal output - 'process = subprocess.Popen(command, stdout=subprocess.PIPE, shell=True)'

# %%
command = f'git -C {eucalyptus_project_path} tag -l --format="%(refname:short)" | sort'
process = subprocess.Popen(command, stdout=subprocess.PIPE, shell=True)
tags = list (line.strip().decode("utf-8") for line in process.stdout)
print(tags)
# Out:
# ['1.0-beta', '1.4', '1.5.0', '1.5.1', '1.5.2', '1.6.1', '2.0.0', '2.0.1', '2.0-beta', '2.0-branch', '3.0.0', '3.0.1', '3.0-alpha1', '3.0-beta2', '3.0-beta3', '3.0-beta4', '3.0-beta5', '3.0-beta6', '3.0-rc1', '3.0-rc2', '3.0-rc3', '3.1.0', '3.1.1', '3.1.2', '3.1-alpha2', '3.1-beta1', '3.2.0', '3.2.1', '3.2.2', '3.3.0', '3.3.0.1', '3.3.1', '3.3.2', '3.3-m1', '3.3-m2', '3.3-m3', '3.3-m4', '3.3-m5', '3.3-m6', '3.4.0', '3.4.1', '3.4.2', 'ha-baseline', 'jaunty', 'karmic', 'v4.0.0', 'v4.0.1', 'v4.0.2', 'v4.1.0', 'v4.1.1', 'v4.1.2', 'v4.2.0', 'v4.2.1', 'v4.2.2', 'v4.3.0', 'v4.3.0.1', 'v4.3.1', 'v4.3.1.1', 'v4.4.0', 'v4.4.1', 'v4.4.2']

# %%
import re

versions = {}
major_minor_patch_versions = []

pattern = "^v?(\d\.\d)(\.\d)?$"

for tag in tags:
    m = re.search(pattern, tag)
    if m is not None:
        if not versions.get(m.groups()[0], False):
            versions[m.groups()[0]] = tag
        major_minor_patch_versions.append(tag)
               
major_minor_versions = list(versions.values())

print("Major_minor : ", major_minor_versions)
print("Major_minor_patch : ", major_minor_patch_versions)
# Out:
# Major_minor :  ['1.4', '1.5.0', '1.6.1', '2.0.0', '3.0.0', '3.1.0', '3.2.0', '3.3.0', '3.4.0', 'v4.0.0', 'v4.1.0', 'v4.2.0', 'v4.3.0', 'v4.4.0']
# Major_minor_patch :  ['1.4', '1.5.0', '1.5.1', '1.5.2', '1.6.1', '2.0.0', '2.0.1', '3.0.0', '3.0.1', '3.1.0', '3.1.1', '3.1.2', '3.2.0', '3.2.1', '3.2.2', '3.3.0', '3.3.1', '3.3.2', '3.4.0', '3.4.1', '3.4.2', 'v4.0.0', 'v4.0.1', 'v4.0.2', 'v4.1.0', 'v4.1.1', 'v4.1.2', 'v4.2.0', 'v4.2.1', 'v4.2.2', 'v4.3.0', 'v4.3.1', 'v4.4.0', 'v4.4.1', 'v4.4.2']

# %%
major_minor_patch_versions1 = ['1.4','1.5.0','1.5.1','1.5.2','1.6.1','2.0.0','2.0.1','3.0.0','3.0.1','3.1.0','3.1.1','3.1.2','3.2.0','3.2.1',
                              '3.2.2','3.3.0','3.3.1','3.3.2','3.4.0','3.4.1','3.4.2','v4.0.0','v4.0.1','v4.0.2','v4.1.0','v4.1.1','v4.1.2',
                              'v4.2.0','v4.2.1','v4.2.2','v4.3.0','v4.3.1','v4.4.0','v4.4.1','v4.4.2']
major_minor_versions1 = ['1.4','1.5.0','1.6.1','2.0.0','3.0.0','3.1.0','3.2.0','3.3.0','3.4.0','v4.0.0','v4.1.0','v4.2.0','v4.3.0','v4.4.0']

# %% [markdown]
# ### 2.2 Law of Increasing Growth
# 1. Fetch the required data (lines of code, blank lines, comment lines and number of files) for each tag along with their release date using CLOC
# 2. Separate the data as following (also mentioned in section 2.1 of the description document)
#     a) Consider all the three-component versions (major.minor.patch) - Dataset A
#     b) Consider only the minor versions (major.minor) - Dataset B
#
# Note: For example, if there exists any tag like 2.1.0.1, then you can consider it as 2.1.0 provided such a tag does not exist in the data. If both 2.1.0 and 2.1.0.1 exists, then you can ignore the latter

# %% [markdown]
# Code hint:
# To set the project to a required tag - "command = f'git -C {project_path} reset --hard {tag}'"
# For each tag, pass the command to the terminal, invoke cloc tool to get the necessary data in the required format (json, md,...), read the terminal output and store the data

# %%
command = ""
for version in major_minor_patch_versions:
    command += f'git -C {eucalyptus_project_path} reset --hard {version} && cloc {eucalyptus_project_path} --csv --quiet > data/{version}.csv && '

command = command[:-2]
process = subprocess.Popen(command, stdout=subprocess.PIPE, shell=True)
# Out:
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/component/groups/ServiceGroups.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/component/id/ClusterController.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/component/id/ComponentService.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/component/id/Database.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/component/id/Dns.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/component/id/Euare.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/component/id/Eucalyptus.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/component/id/HttpService.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/component/id/Ldap.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/component/id/Notifications.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/component/id/Reporting.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/component/id/Tokens.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/config/ArbitratorConfiguration.groovy
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/config/BaseSystemConfiguration.groovy
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/config/ComponentConfiguration.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/config/ConfigurationService.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/configurable/AbstractConfigurableProperty.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/configurable/Configurable.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/configurable/ConfigurableClass.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/configurable/ConfigurableField.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/configurable/ConfigurableFieldType.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/configurable/ConfigurableIdentifier.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/configurable/ConfigurableProperty.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/configurable/ConfigurablePropertyBuilder.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/configurable/ConfigurablePropertyException.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/configurable/Configurables.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/configurable/MultiDatabasePropertyEntry.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/configurable/Properties.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/configurable/PropertiesDiscovery.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/configurable/PropertyChangeListener.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/configurable/PropertyChangeListeners.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/configurable/PropertyDirectory.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/configurable/PropertyTypeParser.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/configurable/SingletonDatabasePropertyEntry.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/configurable/StaticDatabasePropertyEntry.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/configurable/StaticPropertyEntry.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/context/Context.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/context/Contexts.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/context/DelegatingContextSupport.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/context/IllegalContextAccessException.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/context/NoSuchContextException.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/context/ServiceContext.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/context/ServiceContextConfigurationException.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/context/ServiceContextErrorFilter.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/context/ServiceContextManager.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/context/ServiceDispatchException.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/context/ServiceInitializationException.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/context/ServiceStateException.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/crypto/BaseSecurityProvider.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/crypto/CertificateProvider.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/crypto/Certs.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/crypto/Ciphers.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/crypto/Crypto.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/crypto/CryptoProvider.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/crypto/Digest.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/crypto/Hmac.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/crypto/HmacProvider.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/crypto/Hmacs.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/crypto/KeyStore.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/crypto/Signatures.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/crypto/util/AbstractKeyStore.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/crypto/util/B64.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/crypto/util/BCSslSetup.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/crypto/util/Base64Handler.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/crypto/util/PEMFiles.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/crypto/util/SecurityHeader.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/crypto/util/SecurityParameter.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/crypto/util/SslSetup.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/crypto/util/SslUtils.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/crypto/util/Timestamps.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/crypto/util/WSSecurity.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/crypto/util/WssIdResolver.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/empyrean/Arbitrator.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/empyrean/Empyrean.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/empyrean/EmpyreanMessages.groovy
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/empyrean/EmpyreanService.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/empyrean/PropertiesService.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/empyrean/configuration/ServiceRegistrationManager.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/empyrean/configuration/ServiceRegistrationMessages.groovy
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/entities/AbstractOwnedPersistent.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/entities/AbstractStatefulPersistent.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/entities/AbstractStatefulStacklessPersistent.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/entities/AccountMetadata.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/entities/BaseEntities.groovy
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/entities/DatabasesPersistenceContextLookupInterceptor.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/entities/DelegatingInterceptor.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/entities/Entities.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/entities/EntityCache.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/entities/EntityWrapper.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/entities/GlobalUserMetadata.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/entities/Interceptors.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/entities/PersistenceContextDiscovery.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/entities/PersistenceContexts.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/entities/PersistenceExceptions.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/entities/RecoverablePersistenceException.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/entities/TransactionCallbackException.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/entities/TransactionException.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/entities/TransactionExecutionException.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/entities/TransactionInternalException.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/entities/TransactionResource.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/entities/Transactions.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/entities/TransientEntityException.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/entities/UserMetadata.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/event/AbstractNamedRegistry.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/event/ClockTick.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/event/Event.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/event/EventFailedException.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/event/EventListener.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/event/EventListenerDiscovery.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/event/GenericEvent.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/event/Hertz.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/event/ListenerRegistry.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/event/Listeners.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/event/ReferentialEvent.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/event/StatefulNamedRegistry.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/event/SystemClock.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/http/MappingHttpMessage.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/http/MappingHttpRequest.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/http/MappingHttpResponse.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/images/InstanceNotTerminatedException.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/images/NoSuchImageException.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/records/BaseRecord.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/records/EventClass.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/records/EventRecord.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/records/EventType.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/records/LogFileRecord.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/records/Logs.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/records/Record.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/records/RecordFilter.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/records/RecordLevel.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/reporting/event/AddressEvent.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/reporting/event/EventActionInfo.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/reporting/event/InstanceCreationEvent.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/reporting/event/InstanceUsageEvent.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/reporting/event/ResourceAvailabilityEvent.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/reporting/event/S3EventSupport.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/reporting/event/S3ObjectEvent.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/reporting/event/SnapShotEvent.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/reporting/event/VolumeEvent.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/scripting/Groovyness.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/scripting/ScriptExecutionFailedException.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/system/Ats.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/system/BaseDirectory.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/system/Capabilities.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/system/DirectoryBootstrapper.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/system/EucaLayout.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/system/SubDirectory.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/system/Threads.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/system/log/EucaHierarchy.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/system/log/EucaLogger.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/system/log/EucaLoggerFactory.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/system/log/EucaLoggingEvent.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/system/log/EucaLoggingOutputStream.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/system/log/EucaPatternLayout.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/system/log/EucaPatternParser.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/system/log/EucaRootLogger.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/system/log/LoggingResetter.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/system/log/NullEucaLogger.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/upgrade/Upgrades.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/upgrade/entity-profile.groovy
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/upgrade/list-upgrades.groovy
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/ByteArray.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/Callback.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/ChannelBufferStreamingInputStream.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/Cidr.groovy
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/Classes.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/CollectionUtils.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/Composite.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/CompositeHelper.groovy
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/Composites.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/DNSProperties.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/Dates.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/DispatchingClient.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/Emails.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/EucalyptusCloudException.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/EucalyptusClusterException.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/EucalyptusUnsupportedOperationException.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/Exceptions.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/Expendable.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/ExposedCommand.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/Fields.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/Filterable.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/FinalReturn.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/FullName.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/HasFullName.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/HasName.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/HasNaturalId.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/HasParent.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/HasSideEffect.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/IO.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/Internets.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/Intervals.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/InvalidCredentialsException.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/LockResource.groovy
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/LogUtil.groovy
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/Lookups.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/Mappable.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/Mbeans.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/NamespaceMappingXMLStreamWriter.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/NoopPreferences.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/NoopPreferencesFactory.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/Numbers.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/Ordered.groovy
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/OwnerFullName.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/Pair.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/Parameters.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/PermissionedRollingFileAppender.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/RESTException.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/RestrictedType.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/RestrictedTypes.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/ServiceProcess.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/Strings.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/Subnets.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/SynchronousClient.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/Templates.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/ThreadLocalRandom.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/TimedEvictionSet.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/Timers.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/Tx.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/TypeMapper.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/TypeMappers.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/TypedContext.groovy
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/TypedKey.groovy
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/UniqueIds.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/UserDatas.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/Wrapper.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/Wrappers.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/XMLParser.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/async/AsyncRequest.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/async/AsyncRequestHandler.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/async/AsyncRequests.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/async/AsyncResponseFuture.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/async/BroadcastCallback.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/async/CallbackFactory.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/async/CallbackListenerSequence.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/async/Callbacks.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/async/CheckedListenableFuture.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/async/ConnectionException.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/async/DelegatingRemoteCallback.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/async/Factory.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/async/FailedRequestException.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/async/Futures.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/async/MessageCallback.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/async/NOOP.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/async/NoResponseException.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/async/RemoteCallback.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/async/RemoteCallbackFactory.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/async/Request.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/async/RequestException.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/async/RequestHandler.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/async/RequestInitializationException.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/async/RetryableConnectionException.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/async/SubjectMessageCallback.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/async/SubjectRemoteCallbackFactory.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/async/UnconditionalCallback.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/async/UnknownMessageTypeException.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/concurrent/AbstractCheckedFuture.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/concurrent/AbstractFuture.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/concurrent/AbstractListenableFuture.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/concurrent/CheckedFuture.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/concurrent/GenericCheckedListenableFuture.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/concurrent/ListenableFuture.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/dns/DnsResolvers.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/dns/DomainNameRecords.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/dns/DomainNames.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/dns/NameserverResolver.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/fsm/AbstractTransitionAction.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/fsm/AtomicMarkedState.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/fsm/Automata.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/fsm/ExistingTransitionException.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/fsm/HasStateMachine.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/fsm/OrderlyTransitionException.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/fsm/SplitTransition.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/fsm/StateMachine.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/fsm/StateMachineBuilder.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/fsm/TransitionAction.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/fsm/TransitionException.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/fsm/TransitionHandler.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/fsm/TransitionImpl.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/fsm/TransitionListener.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/fsm/TransitionListenerException.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/fsm/TransitionRecord.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/fsm/TransitionRule.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/fsm/Transitions.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/techpreview/TechPreview.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/util/techpreview/TechPreviews.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/ws/Client.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/ws/EucalyptusRemoteFault.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/ws/EucalyptusWebServiceException.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/ws/Handlers.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/ws/Role.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/ws/ServiceNotReadyException.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/ws/StackConfiguration.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/ws/TransportDefinition.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/ws/WebServices.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/ws/WebServicesException.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/ws/client/NioClient.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/ws/client/ServiceDispatcher.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/ws/handlers/BindingHandler.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/ws/handlers/ClusterWsSecHandler.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/ws/handlers/HmacHandler.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/ws/handlers/InternalWsSecHandler.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/ws/handlers/MessageStackHandler.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/ws/handlers/NodeWsSecHandler.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/ws/handlers/QueryTimestampHandler.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/ws/handlers/ResponseHandler.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/ws/handlers/RestfulMarshallingHandler.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/ws/handlers/SignatureHandlerUtils.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/ws/handlers/SoapMarshallingHandler.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/ws/handlers/UserWsSecHandler.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/ws/handlers/WsSecHandler.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/ws/handlers/http/HttpException.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/ws/handlers/http/HttpUtils.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/ws/handlers/http/NioHttpDecoder.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/ws/handlers/http/NioHttpRequestEncoder.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/ws/protocol/AddressingHandler.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/ws/protocol/BaseQueryBinding.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/ws/protocol/OperationParameter.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/ws/protocol/QueryBindingInfo.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/ws/protocol/RequestLoggingFilter.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/ws/protocol/RequestLoggingFilterDiscovery.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/ws/protocol/RequestLoggingFilters.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/ws/protocol/RequiredQueryParams.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/ws/protocol/SoapHandler.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/ws/server/DuplicatePipelineException.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/ws/server/FilteredPipeline.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/ws/server/LegacyHBPipeline.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/ws/server/NioMessageReceiver.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/ws/server/NioServerHandler.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/ws/server/NoAcceptingPipelineException.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/ws/server/Pipelines.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/ws/server/ServiceAccessLoggingHandler.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/ws/server/ServiceContextHandler.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/ws/server/ServiceHackeryHandler.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/ws/server/Statistics.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/ws/util/CredentialProxy.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/ws/util/ErrorHandlerSupport.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/ws/util/HmacUtils.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/ws/util/ReplyQueue.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/ws/util/RequestQueue.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/com/eucalyptus/ws/util/SerializationUtils.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/edu/ucsb/eucalyptus/cloud/Extra.groovy
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/edu/ucsb/eucalyptus/cloud/entities/SystemConfiguration.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/edu/ucsb/eucalyptus/constants/IsData.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/edu/ucsb/eucalyptus/msgs/BaseCallerContext.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/edu/ucsb/eucalyptus/msgs/BaseData.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/edu/ucsb/eucalyptus/msgs/BaseDataChunk.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/edu/ucsb/eucalyptus/msgs/BaseMessage.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/edu/ucsb/eucalyptus/msgs/BaseMessageSupplier.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/edu/ucsb/eucalyptus/msgs/BaseMessages.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/edu/ucsb/eucalyptus/msgs/CallerContext.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/edu/ucsb/eucalyptus/msgs/DNS.groovy
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/edu/ucsb/eucalyptus/msgs/EvaluatedIamConditionKey.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/edu/ucsb/eucalyptus/msgs/GroovyAddClassUUID.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/edu/ucsb/eucalyptus/msgs/GroovyAddClassUUIDASTTransformation.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/edu/ucsb/eucalyptus/msgs/HasRequest.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/edu/ucsb/eucalyptus/msgs/Messages.groovy
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/edu/ucsb/eucalyptus/msgs/StreamedBaseMessage.java
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/edu/ucsb/eucalyptus/msgs/Tags.groovy
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/edu/ucsb/eucalyptus/msgs/Unimplemented.groovy
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/clc/modules/msgs/src/main/java/edu/ucsb/eucalyptus/msgs/VPN.groovy
# ...
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/devel/grabdbs.sh
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/devel/groovy.sh
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/devel/ha_transit.pl
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/devel/log2dot.sh
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/devel/mapIamQuotasToActions.groovy
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/devel/nc-log-gnuplot.pl
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/devel/populate_canonical_ids.groovy
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/devel/postgres_alises.sh
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/devel/project.sh
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/devel/quick_cc.pl
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/devel/quick_cloud.pl
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/devel/quick_ha.pl
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/devel/quick_nc.pl
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/devel/quick_svc_lookup.pl
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/devel/revcount.sh
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/devel/runJUnitTest.sh
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/devel/runTest.sh
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/devel/tcpdump.sh
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/doxygen/Makefile
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/doxygen/extra_pages/changelog.txt
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/doxygen/extra_pages/cluster_project.txt
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/doxygen/extra_pages/doxygen.txt
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/doxygen/extra_pages/install.txt
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/doxygen/extra_pages/license.txt
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/doxygen/extra_pages/node_project.txt
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/doxygen/extra_pages/readme.txt
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/doxygen/extra_pages/vmware_broker_project.txt
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/doxygen/html_includes/customdoxygen.css
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/doxygen/html_includes/footer.html
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/doxygen/html_includes/header.html
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/doxygen/html_includes/layoutFileName_1_6.xml
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/doxygen/html_includes/layoutFileName_1_8.xml
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/doxygen/setup.sh
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/extras/ganglia.sh
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/extras/nagios.sh
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/m4/python.m4
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/net/config-eucanetd.h
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/net/eucanetd.c
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/net/eucanetd.h
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/net/globalnetwork.c
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/net/globalnetwork.h
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/net/ipt_handler.c
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/net/ipt_handler.h
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/node/client-marshal-fake.c
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/node/handlers_default.c
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/node/handlers_kvm.c
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/node/handlers_xen.c
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/node/hooks.c
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/node/hooks.h
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/node/libvirt_tortura.c
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/node/xml.c
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/node/xml.h
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/project/.cproject
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/project/.project
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/project/.settings/org.eclipse.cdt.codan.core.prefs
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/storage/OSGclient.c
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/storage/SCclient.c
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/storage/backing.c
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/storage/backing.h
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/storage/blobstore.c
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/storage/blobstore.h
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/storage/diskutil.c
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/storage/diskutil.h
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/storage/ebs_utils.c
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/storage/ebs_utils.h
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/storage/http.c
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/storage/http.h
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/storage/imager/Makefile
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/storage/imager/cache.c
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/storage/imager/cache.h
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/storage/imager/cmd.h
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/storage/imager/cmd_bundle.c
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/storage/imager/cmd_convert.c
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/storage/imager/cmd_extract.c
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/storage/imager/cmd_fsck.c
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/storage/imager/cmd_prepare.c
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/storage/imager/cmd_upload.c
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/storage/imager/diskfile.c
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/storage/imager/diskfile.h
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/storage/imager/imager.c
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/storage/imager/imager.h
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/storage/imager/img.c
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/storage/imager/img.h
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/storage/imager/test-imager
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/storage/imager/vmdk.c
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/storage/imager/vmdk.h
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/storage/imager/vmdk_shim.c
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/storage/iscsi.c
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/storage/iscsi.h
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/storage/map.c
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/storage/map.h
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/storage/objectstorage.c
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/storage/objectstorage.h
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/storage/sc-client-marshal-adb.c
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/storage/sc-client-marshal.h
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/storage/storage-controller.c
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/storage/storage-controller.h
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/storage/storage-windows.c
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/storage/storage-windows.h
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/storage/vbr.c
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/storage/vbr.h
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/tools/authorize-migration-keys.pl
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/tools/connect_iscsitarget.pl
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/tools/connect_iscsitarget_main.pl
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/tools/connect_iscsitarget_sc.pl
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/tools/conntrack_kernel_params
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/tools/create-loop-devices
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/tools/detach.pl
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/tools/disconnect_iscsitarget.pl
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/tools/disconnect_iscsitarget_main.pl
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/tools/disconnect_iscsitarget_sc.pl
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/tools/dynserv.pl
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/tools/euca-lictool
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/tools/euca-upgrade
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/tools/euca_arpt
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/tools/eucalyptus-backup-restore
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/tools/gen_kvm_libvirt_xml
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/tools/generate-migration-keys.sh
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/tools/get_bundle
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/tools/get_iscsitarget.pl
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/tools/get_sys_info
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/tools/getstats.pl
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/tools/getstats_net.pl
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/tools/getusercred.sh
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/tools/imaging/Makefile
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/tools/imaging/bin/euca-run-workflow
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/tools/imaging/eucatoolkit/stages/__init__.py
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/tools/imaging/eucatoolkit/stages/cryptoutils.py
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/tools/imaging/eucatoolkit/stages/downloadimage.py
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/tools/imaging/eucatoolkit/stages/downloadmanifest.py
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/tools/imaging/eucatoolkit/stages/downloadpart.py
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/tools/imaging/eucatoolkit/stages/processutils.py
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/tools/imaging/setup.py
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/tools/iscsitarget_common.pl
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/tools/libvirt-kvm-windows-example.xml
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/tools/libvirt-xen-windows-example.xml
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/tools/libvirt.xsl
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/tools/nc-hooks/example.sh
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/tools/nc-hooks/libvirt-check.sh
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/tools/partition2disk
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/tools/populate_arp.pl
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/util/adb-helpers.h
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/util/adb-service-helpers.h
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/util/atomic_file.c
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/util/atomic_file.h
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/util/config.c
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/util/config.h
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/util/euca_axis.c
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/util/euca_axis.h
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/util/euca_file.c
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/util/euca_file.h
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/util/euca_mountwrap.c
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/util/euca_rootwrap.c
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/util/euca_string.c
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/util/euca_string.h
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/util/fault.c
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/util/fault.h
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/util/faults/en_US/1001.xml
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/util/faults/en_US/1002.xml
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/util/faults/en_US/1003.xml
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/util/faults/en_US/1004.xml
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/util/faults/en_US/1005.xml
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/util/faults/en_US/1006.xml
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/util/faults/en_US/1008.xml
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/util/faults/en_US/1009.xml
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/util/faults/en_US/1010.xml
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/util/faults/en_US/1011.xml
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/util/faults/en_US/1012.xml
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/util/faults/en_US/1013.xml
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/util/faults/en_US/1014.xml
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/util/faults/en_US/1015.xml
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/util/faults/en_US/1500.xml
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/util/faults/en_US/1501.xml
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/util/faults/en_US/2000.xml
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/util/faults/en_US/2001.xml
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/util/faults/en_US/2002.xml
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/util/faults/en_US/2003.xml
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/util/faults/en_US/common.xml
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/util/faults/ru_RU/1002.xml
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/util/faults/ru_RU/1234.xml
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/util/faults/ru_RU/1235.xml
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/util/faults/ru_RU/common.xml
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/util/hash.c
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/util/hash.h
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/util/instance33.h
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/util/log.c
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/util/log.h
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/util/sensor.c
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/util/sensor.h
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/util/sequence_executor.c
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/util/sequence_executor.h
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/util/template.c
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/util/template.h
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/util/utf8.c
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/util/utf8.h
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/util/wc.c
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/util/wc.h
# Unable to read /home/arnaubuntu/Documents/SE/eucalyptus/wsdl/eucalyptus_sc.wsdl
# 1 error:
# Line count, exceeded timeout:  /home/arnaubuntu/Documents/SE/eucalyptus/net/globalnetwork.c

# %%
#command = f'git -C {eucalyptus_project_path} tag -l --format="%(refname:short)|%(creatordate:short)" | sort -r' # to get the release date
#process = subprocess.Popen(command, stdout=subprocess.PIPE, shell=True)
# Your code to obtain the release date of each tag and combine it with the data obtained in the previous cell. Final data should have
# #lines of code, #comments, #files, #blanks, #release date

# %%
# Your code here to get the versions of the form major.minor

# %%
# Your code here to get the versions of the form major.minor.patch

# %% [markdown]
# #### Visualization
# 1. x-axis = version, y-axis = number
#     i) for tags of the type major.minor.patch
#     ii) for tags of the type major.minor
#
# 2. x-axis = date, y-axis = number
#     i) for tags of the type major.minor.patch
#     ii) for tags of the type major.minor
#
# For easy comparison, place the plots with the versions on x-axis should be on the top (0,0) and (1,0) and their corresponding plots with date on the x-axis right below them (1,0) and (1,1)

# %%
import pandas as pd
import matplotlib.pyplot as plt

fig, axs = plt.subplots(2, 2, figsize=(15, 15))

df1 = pd.read_csv("LIG_major_minor.csv", delimiter = ',')
df2 = pd.read_csv("LIG_major_minor_patch.csv", delimiter = ',')

#display(df2)

y1=df1["nb_code"]
x1=df1["date"]
x2=df1["major.minor"]
y3=df2["nb_code"]
x3=df2["date"]
x4=df2["major.minor.patch"]

axs[0, 0].plot(x1,y1)
axs[0, 0].tick_params('x', labelrotation=90)

axs[1, 0].plot(x2,y1)

axs[0, 1].plot(x3,y3)
axs[0, 1].tick_params('x', labelrotation=90)

axs[1, 1].plot(x4,y3)
axs[1, 1].tick_params('x', labelrotation=90)

plt.show()

# %% [markdown]
# ### Questions:
# 1. Do you find any difference between the plot that is having date in the x-axis and the plot that is having tag in the x-axis? If yes, then what is the difference? If no, then why is it same?

# %% [markdown]
# 2. Which type of plot is preferable for software evolution analysis?
#     a) date in x-axis
#     b) tag in x-axis
# Why?

# %% [markdown]
# tag in x-axis, date does not reflect wether huge update are made. One cannot justify the growth of the project with date but with tags it make more sens.

# %% [markdown]
# 3. Choose an option regarding the growth of the software by considering Dataset A. Motivate your choice using a 1d regression plot (below).
#     a) Linear
#     b) Sub-linear
#     c) Super-linear

# %%
plt.figure(figsize=(7,7))
# Your code for regression plot

# %% [markdown]
# ### Correlation
# Correlation is generally used to analyse the relationship between variables. Here, analyse the relationship between the number of lines of code and the number of files using Spearman correlation and Pearson correlation by considering Dataset A. Report the correlation upto 3 decimal places

# %%
# Your code for correlation
pearson_corr = scipy.stats.pearsonr(df2["nb_code"], df2["nb_nfiles"])[0]

spearman_corr = scipy.stats.spearmanr(df2["nb_code"], df2["nb_nfiles"])[0]

print(f'Pearson correlation : {pearson_corr:.3f}')
print(f'Spearman correlation : {spearman_corr:.3f}')
# Out:
# Pearson correlation : 0.993
# Spearman correlation : 0.977

# %% [markdown]
# ### Questions:
# 4. Do you find any difference in correlation values between Pearson and Spearman? Which one is preferable for this use case? why?

# %% [markdown]
# Spearman and Peasron both show high correlation.

# %% [markdown]
# 5. Based on the above correlation value, how much is the number of lines of code related to the number of files?

# %% [markdown]
# ### Prediction
# Consider Dataset A for this task. Drop the last two data points in "number of lines of code" (LOC) (i.e. drop (LOC) corresponding to v4.4.1 and v4.4.2) and forecast the values for (LOC) for v4.4.1 and v4.4.2 using a basic linear/polynimial regression model.
# 1. Drop the last two data points
# 2. Build a basic regression model
# 3. Ask the model to forecast the next two data points
# 4. Plot the LOC original and forecasted in the same plot. x-axis = date, y-axis = number of lines of code

# %%
df3 = df2.tail(2)


df2.drop(index=df2.index[-2:])

X = df2[["nb_blank","nb_comment","nb_nfiles"]]
y = df2["nb_code"]


model = LinearRegression()
model.fit(X, y)


X_predict = df3[["nb_blank","nb_comment","nb_nfiles"]]
y_predict = model.predict(X_predict)

print("data =\n", df3["nb_code"])

print("prediction=\n", y_predict)
# Out:
# data =
#  33    532915
# 34    533292
# Name: nb_code, dtype: int64
# prediction=
#  [521785.43260368 522053.91601528]

# %%
a = df2["nb_code"]
b = df2["nb_nfiles"]

result = scipy.stats.linregress(a, b)

# %%
# Your code here

# %%
# Your plotting code here

# %% [markdown]
# ### Questions:
# 6. What is the polynomial degree that you adopted to build the model? Why?

# %% [markdown]
# 1

# %% [markdown]
# 7. What is the coefficient of determination? (R-squared)

# %% [markdown]
# 8. What is the Root mean square error for the forecasted values?

# %% [markdown]
# ### Filtering on coding language

# %% [markdown]
# Consider the prominent langugages used in this software project and plot the distribution of their LOC in a pie chart for the first and the last versions

# %%
df_current = pd.read_csv("data/data.csv", delimiter = ',')
df_14 = pd.read_csv("data/data2.csv", delimiter = ',')

# %%
def compute_pie(df)  :  
    languages = df["language"]
    sizes = df["code"]

    total = sum(sizes)
    displayed_languages = {"other": 0}

    for language, size in zip(languages, sizes):
        if size < 0.01 * total:
            displayed_languages["other"] += int(size)
        else:
            displayed_languages[language] = int(size)
    return displayed_languages
        
dict1 = compute_pie(df_current)
dict2 = compute_pie(df_14)

fig, axs = plt.subplots(1, 2, figsize=(11, 11))
axs[0].pie(dict1.values(), labels=dict1.keys(), autopct='%1.1f%%')
axs[1].pie(dict2.values(), labels=dict2.keys(), autopct='%1.1f%%')
plt.plot()
# Out:
# []

# %% [markdown]
# ### Question:
# 9. Do you find any significant difference in the distribution of the language used in the software project between its first and the last version? If so, what is the difference and how much is it?

# %% [markdown]
# Bourne shell is no more one of the main language in the project. Java proportion is greater in the lastest version

# %% [markdown]
# ### Law of increasing growth for coding langugages

# %% [markdown]
# Get the LOC for each of the considered prominent langugages (as above) for each version of the form major.minor.patch
# 1) Plot the date (x-axis) vs LOC (y-axis)
# 2) Plot the date (x-axis) vs proportional LOC (y-axis). Proportional is LOC of a language/total number of LOC

# %%
dfs=[]
for version in major_minor_patch_versions:
    dfs.append(pd.read_csv(f'data/{version}.csv', delimiter = ','))

for df in dfs:
    df.drop(df.tail(1).index,inplace=True)    
    


#df_301 = pd.read_csv("data3.csv", delimiter = ',')

# %%
important_languages=["Java","C","Groovy","XML","C/C++ Header","Bourne Shell"]
fig, axs = plt.subplots(figsize=(10,9))
    

for lang in important_languages:
    l = [int(df[df['language']==lang]["code"]) for df in dfs]
    axs.plot(major_minor_patch_versions, l)

plt.legend(important_languages)    
plt.show()

# %% [markdown]
# ### Question:
# 10. Does the prominent languages considered by you obey laws of increasing growth?

# %% [markdown]
# yes it does

# %% [markdown]
# 11. Does this software project obey the Law of Increasing Growth?

# %% [markdown]
# yes it does

# %% [markdown]
# ### Modify the CLOC parameters

# %% [markdown]
# 1. Exclude all bank lines and verify if the Law of Increasing Growth still holds good for this filtering

# %%
# Your code and plot here

# %% [markdown]
# 2. Exclude all comment lines and verify if the Law of Increasing Growth still holds good for this filtering

# %%
# Your code and plot here

# %% [markdown]
# 3. Exclude all non-code files (or consider prominent coding langugages used in the project) and and verify if the Law of Increasing Growth still holds good for this filtering

# %%
# Your code and plot here

# %% [markdown]
# ### 2.3 Law of Continuing Change
# 1. Using CLOC tool, find the features such as number of lines of code that are added, modified, removed and same between two consecutive versions
# 2. Consider all the three component versions (major.minor.patch) - Dataset A
# 3. Consider only the minor versions (major.minor) - Dataset B
# 4. Having all the features in the same plot, create two plots (one for Dataset A and another for Dataset B) the outcomes with date on x-axis and the number on y-axis.
# 5. Make a subplot of all the features
#
# Code hint:
# For each pair of tags, set the original project to the required tag and the copy of the original project to the next tag.
# To get the required data in json format - "command = f'CLOC/cloc --git --diff {first_project_path} {second_project_path} --json'"

# %%
eucalyptus_project_path = '' # your project path here
eucalyptus_copy_project_path = '' # your path to the copy of your project here
major_minor_patch_versions = '' #set of version that you would like to consider for this analysis

# %%
# Your code here to get the data

# %%
# Your code here to get the dates corresponding to the tags

# %%
# Your plotting code here (all the features in a single plot)

# %%
# Your plotting code here, different plot for each feature
fig,axes = plt.subplots(2,2)

# %% [markdown]
# ### Questions:
# 1. Do you find the Law of Continuing Change holding good here? Prove it empirically.

# %% [markdown]
# 2. Does the law of increasing growth too hold good here?

# %% [markdown]
# ### Law of continuing change for coding languages
# Consider the prominent languages used in this software project for versions of the form major.minor.patch
# 1. Obtain the number of lines of code that are added, modified, removed and same between two consecutive versions
# 2. Make plots for each parameter (added, modified, removed and same) with date on x-axis
#     a) y-axis number of lines of code
#     b) y-axis proportional number of lines of code (number of lines of code of that language/total number of lines of code)

# %%
# Your code here

# %%
# Your plotting code here
fig,axes = plt.subplots(2,2)

# %% [markdown]
# ### Question:
# 3. Does the law of continuing change obey here for all the considered prominent langugages? Comment on the rate of growth.

# %% [markdown]
# 4. Does this software project obey Law of Continuing Change?
